# %% [markdown]
# # MFRE Python Prep Assignment
#
# **Master of Food and Resource Economics | University of British Columbia**
#
# ---
#
# ## Instructions
#
# - Complete every question by writing Python code in the cells provided.
# - Add **at least one comment** per code cell to explain your thinking.
# - Run each cell as you go (Shift + Enter) to check your output.
# - When finished: **File → Save**, then email the `.ipynb` file to Olivier Ntwali ( Instructions below).
#
# > **Tip:** If a cell throws an unexpected error, re-read the question carefully,
# > then check that you ran all the cells above it first
# > (Kernel → Restart & Run All resets everything cleanly).
#
# ---
#
# ## What this assignment covers
#
# | Questions | Skills tested | Notebook |
# |---|---|---|
# | 1 – 4 | Variables, arithmetic, conditionals, loops, functions | Part A |
# | 5 – 7 | Lists, dictionaries, string methods, comprehensions | Part B |
# | 8 | Error handling (`try / except`) | Part B |
# | 9 | Pandas — DataFrame, filter, `groupby` | Part B |
#
# ---

# %% [markdown]
# ## Your details
#
# Fill in the cell below before you start.

# %%
# ── Fill in your details ──────────────────────────────────────────
student_name  = 'Your Name'
student_email = 'your.email@student.ubc.ca'

print(f'Assignment submitted by: {student_name} ({student_email})')
# Out:
# Assignment submitted by: Your Name (your.email@student.ubc.ca)

# %% [markdown]
# ---
# ## Dataset: Global Crop Production
#
# All questions in this assignment use the dataset defined in the cell below.
# **Run this cell first before attempting any question.**

# %%
# ── Dataset — run this cell first ────────────────────────────────
# Crop yield data (tonnes per hectare, approximate 2023 values)

countries  = ['Canada', 'USA',  'Australia', 'Russia', 'France']
crops      = ['wheat',  'corn', 'wheat',     'wheat',  'wheat' ]
yields_tha = [3.50,     9.80,   2.10,        3.00,     7.20    ]   # t/ha
exports_Mt = [22.0,     26.5,   21.0,        33.0,     18.0    ]   # million tonnes

# Water footprint of selected commodities (litres per kg):
water_footprint = {
    'wheat':   1827,
    'corn':    1222,
    'rice':    2497,
    'soy':     2145,
    'beef':   15400,
}

# Conversion factors: 1 t/ha → bushels/acre
bushel_factors = {
    'wheat':  14.87,
    'corn':   39.37,
    'canola': 44.09,
    'soy':    14.87,
}

# Messy region names (as they might arrive from a spreadsheet export):
raw_regions = ['  sub-saharan africa ', 'EAST ASIA & PACIFIC',
               'latin america  ', ' North America', 'EUROPE']

print('Dataset loaded successfully ✓')
# Out:
# Dataset loaded successfully ✓

# %% [markdown]
# ---
# ## Question 1: Variables and Arithmetic  *(Part A)*
#
# Using the `yields_tha` list and the country/crop information from the setup cell:

# %% [markdown]
# **a)** Calculate and print the **average wheat yield** across all five entries.
#
# **b)** The USA has the highest yield in the dataset (9.80 t/ha — corn). Calculate how many times higher
# the USA's yield is compared to Australia's yield. Print the result rounded to **2 decimal places**.
#
# **c)** Convert Canada's wheat yield from t/ha to **bushels per acre**.
# The conversion factor for wheat is in `bushel_factors['wheat']`.
# Print the result rounded to 1 decimal place.

# %%
# Question 1 — your code here

# %% [markdown]
# ---
# ## Question 2: Conditional Statements  *(Part A)*

# %% [markdown]
# Write code (using `if` / `elif` / `else`) that takes a yield value and prints a rating:
#
# | Yield (t/ha) | Rating |
# |---|---|
# | ≥ 6.0 | `'Excellent'` |
# | ≥ 3.0 | `'Good'` |
# | ≥ 1.5 | `'Fair'` |
# | < 1.5 | `'Poor'` |
#
# Test your code with: `yield_value = 7.20` (France) and `yield_value = 2.10` (Australia).

# %%
# Question 2 — your code here
yield_value = 7.20   # change this to test different values

# %% [markdown]
# ---
# ## Question 3: Loops  *(Part A)*

# %% [markdown]
# Use a `for` loop with `zip` to loop over `countries`, `crops`, and `yields_tha` together
# and print one line per row in this format:
#
# ```
# Canada    | wheat | 3.50 t/ha
# USA       | corn  | 9.80 t/ha
# ...
# ```
#
# Then, **inside the same loop**, apply your rating logic from Question 2 and add the
# rating to each line:
#
# ```
# Canada    | wheat | 3.50 t/ha | Good
# ```

# %%
# Question 3 — your code here

# %% [markdown]
# ---
# ## Question 4: Writing a Function  *(Part A)*

# %% [markdown]
# Write a function `convert_yield(yield_t_ha, crop)` that:
#
# 1. Looks up the conversion factor for `crop` in `bushel_factors`.
# 2. If the crop is **not** in `bushel_factors`, returns the string
#    `'Error: no conversion factor for <crop>'`.
# 3. Otherwise, returns the yield converted to **bushels per acre** (rounded to 1 decimal place).
#
# Include a **docstring** explaining what the function does, its parameters, and what it returns.
#
# Test it with:
# ```python
# convert_yield(3.50, 'wheat')   # → 52.0
# convert_yield(9.80, 'corn')    # → 385.8
# convert_yield(3.00, 'rice')    # → error message
# ```

# %%
# Question 4 — your code here

# %% [markdown]
# ---
# ## Question 5: Lists and String Methods  *(Part B)*

# %% [markdown]
# The `raw_regions` list in the setup cell contains region names with inconsistent
# capitalisation and stray whitespace — typical of a real spreadsheet export.
#
# **a)** Use a **list comprehension** to create a new list `clean_regions` where every
# name is stripped of leading/trailing spaces and converted to **title case**.
#
# Expected result:
# ```python
# ['Sub-Saharan Africa', 'East Asia & Pacific', 'Latin America', 'North America', 'Europe']
# ```
#
# **b)** Print the clean list as a single comma-separated string on one line.

# %%
# Question 5 — your code here

# %% [markdown]
# ---
# ## Question 6: Dictionaries  *(Part B)*

# %% [markdown]
# Use the `water_footprint` dictionary from the setup cell.
#
# **a)** Print the water footprint of `'wheat'` and `'beef'`.
#
# **b)** Use `.get()` to safely look up `'lamb'`. If it is not in the dictionary,
# return `'Not available'` instead of crashing.
#
# **c)** Use a **dict comprehension** to create a new dictionary `footprint_m3`
# that converts every value from litres/kg to **m³/tonne**
# (the conversion is 1:1 — the numbers are identical, only the units change).
# Print the result.
#
# **d)** Which commodity has the **lowest** water footprint? Use `min()` with a
# `key=` argument to find and print the answer.

# %%
# Question 6 — your code here

# %% [markdown]
# ---
# ## Question 7: List Comprehensions and `enumerate`  *(Part B)*

# %% [markdown]
# **a)** Use a **list comprehension** to create `yields_kg_ha` — the yields from
# `yields_tha` converted to **kg per hectare** (multiply by 1000).
#
# **b)** Use `enumerate` to print each country and its kg/ha yield with a row number,
# in this format:
# ```
# Row 1: Canada    — 3500.0 kg/ha
# Row 2: USA       — 9800.0 kg/ha
# ...
# ```
# *(Hint: `enumerate` starts at 0 by default — use `start=1` to begin at 1.)*
#
# **c)** Using a **list comprehension with a filter**, create a list `high_yield_countries`
# containing only the country names where yield is **above 3.5 t/ha**.

# %%
# Question 7 — your code here

# %% [markdown]
# ---
# ## Question 8: Error Handling  *(Part B)*

# %% [markdown]
# A colleague sends you the following list of reported wheat yields — but some
# entries are missing or corrupt:
#
# ```python
# raw_yields = ['3.50', '2.10', 'N/A', '7.20', '', '3.00', 'missing', '9.80']
# ```
#
# **a)** Write a function `safe_float(value)` that tries to convert `value` to a
# `float` and returns `None` if the conversion fails. Use `try / except`.
#
# **b)** Use a list comprehension and your `safe_float` function to produce
# `parsed_yields` — a list of floats and `None` values.
#
# **c)** Filter out the `None` values to get `clean_yields` (valid numbers only).
#
# **d)** Print the count of valid entries, the mean, the minimum, and the maximum.

# %%
raw_yields = ['3.50', '2.10', 'N/A', '7.20', '', '3.00', 'missing', '9.80']

# Question 8 — your code here

# %% [markdown]
# ---
# ## Question 9: Pandas  *(Part B)*

# %% [markdown]
# Run the cell below to create a Pandas DataFrame from the dataset, then answer
# the questions underneath it.

# %%
import pandas as pd

# Build a DataFrame from the dataset variables defined in the setup cell
df = pd.DataFrame({
    'country':    countries,
    'crop':       crops,
    'yield_t_ha': yields_tha,
    'export_Mt':  exports_Mt,
})

df   # display the table

# %% [markdown]
# **a)** Use `iloc` to display the **first two rows** of the DataFrame.
#
# **b)** Use `loc` to select only the `country` and `yield_t_ha` columns for all rows.
#
# **c)** Filter the DataFrame to show only rows where `yield_t_ha` is **above 3.0**.
#
# **d)** Use `groupby` to calculate the **mean yield** for each unique crop type.
#
# **e)** *(Stretch)* Which country has the highest `export_Mt`? Use `loc` with
# `idxmax()` to find it:
# ```python
# df.loc[df['export_Mt'].idxmax()]
# ```

# %%
# Question 9 — your code here

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before emailing your notebook, confirm each item below:
#
# - [ ] Your name and email are filled in at the top
# - [ ] Every question has code in the answer cell (not just comments)
# - [ ] You have run all cells from top to bottom (no `In [*]` still running)
# - [ ] The notebook is saved (**File → Save**, or Ctrl+S)
#
# **Submit your `.ipynb` file to:** `olivier.ntwali@ubc.ca`
#
# **Subject line:** `MFRE Python Prep — Assignment — [Your Name]`
#
# ---
# *Good luck! Remember: the goal is to practise, not to be perfect.
# If you get stuck, re-read the relevant section in Part A or Part B.*
